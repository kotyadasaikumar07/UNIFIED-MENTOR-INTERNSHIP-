# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
ESGData = pd.read_csv('C:/Users/rocki/OneDrive/Documents/ESGData.csv')

# %%
ESGData.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 1            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 2  Adjusted savings: natural resources depletion ...  NY.ADJ.DRES.GN.ZS   NaN
# 3  Adjusted savings: net forest depletion (% of GNI)  NY.ADJ.DFOR.GN.ZS   NaN
# 4                 Agricultural land (% of land area)     AG.LND.AGRI.ZS   NaN
#
#         1961       1962       1963       1964       1965  ...       2013  \
# 0        NaN        NaN        NaN        NaN        NaN  ...  83.533457
# 1        NaN        NaN        NaN        NaN        NaN  ...  88.129881
# 2        NaN        NaN        NaN        NaN        NaN  ...  11.641062
# 3        NaN        NaN        NaN        NaN        NaN  ...   0.055593
# 4  27.835643  27.826564  27.845522  27.847925  27.866972  ...  36.534503
#
#         2014       2015       2016       2017       2018  2019  2020  2050  \
# 0  83.897596  84.171599  84.510171        NaN        NaN   NaN   NaN   NaN
# 1  87.275323  88.720097  89.308602  90.283638  89.286856   NaN   NaN   NaN
# 2  10.437876   6.277652   5.261868   6.385551   8.190277   NaN   NaN   NaN
# 3   0.079402   0.086177   0.076670   0.085885   0.047916   NaN   NaN   NaN
# 4  36.607475  36.624759  36.610850        NaN        NaN   NaN   NaN   NaN
#
#    Unnamed: 66
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 67 columns]

# %%
col = ESGData.columns
print(col)
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2050',
#        'Unnamed: 66'],
#       dtype='object')

# %%
y = ESGData.loc[19]

# %%
print(ESGData.loc[32])
# Out:
# Country Name                                             Arab World
# Country Code                                                    ARB
# Indicator Name    Labor force participation rate, total (% of to...
# Indicator Code                                       SL.TLF.ACTI.ZS
# 1960                                                            NaN
#                                         ...
# 2018                                                      50.310959
# 2019                                                       50.39837
# 2020                                                            NaN
# 2050                                                            NaN
# Unnamed: 66                                                     NaN
# Name: 32, Length: 67, dtype: object

# %%
list = ['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986','1987', '1988', '1989', '2019', '2020', '2050', 'Unnamed: 66']
updated = ESGData.drop(list, axis = 1)
updated.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 1            Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 2  Adjusted savings: natural resources depletion ...  NY.ADJ.DRES.GN.ZS
# 3  Adjusted savings: net forest depletion (% of GNI)  NY.ADJ.DFOR.GN.ZS
# 4                 Agricultural land (% of land area)     AG.LND.AGRI.ZS
#
#         1990       1991       1992       1993       1994       1995  ...  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 1        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 2   8.096032   8.368431   8.451037   8.247409   7.712396   8.064746  ...
# 3   0.052709   0.087444   0.070674   0.054602   0.058116   0.080551  ...
# 4  31.534601  31.639377  31.741282  32.458657  33.133486  33.742542  ...
#
#         2009       2010       2011       2012       2013       2014  \
# 0  81.809630  82.368101  82.783289  83.120303  83.533457  83.897596
# 1  84.270921  86.959991  87.199474  87.512260  88.129881  87.275323
# 2   8.721330   9.966140  13.002144  12.850205  11.641062  10.437876
# 3   0.051040   0.052809   0.060245   0.061942   0.055593   0.079402
# 4  36.372261  36.425990  36.440808  36.472300  36.534503  36.607475
#
#         2015       2016       2017       2018
# 0  84.171599  84.510171        NaN        NaN
# 1  88.720097  89.308602  90.283638  89.286856
# 2   6.277652   5.261868   6.385551   8.190277
# 3   0.086177   0.076670   0.085885   0.047916
# 4  36.624759  36.610850        NaN        NaN
#
# [5 rows x 33 columns]

# %%
new = updated.columns
new
# Out:
# RangeIndex(start=0, stop=16013, step=1)

# %%
newlist = ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977','1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986','1987', '1988', '1989', '2019', '2020', '2050', 'Unnamed: 66']
updated = ESGData.drop(newlist, axis = 1)
updated = updated.transpose()
updated
# Out:
#           0          1          2         3          4          5      6      \
# 1990        NaN        NaN   8.096032  0.052709  31.534601  10.198358    NaN
# 1991        NaN        NaN   8.368431  0.087444  31.639377  10.910375    NaN
# 1992        NaN        NaN   8.451037  0.070674  31.741282  10.946288    NaN
# 1993        NaN        NaN   8.247409  0.054602  32.458657  10.524052    NaN
# 1994        NaN        NaN   7.712396  0.058116  33.133486  10.940366    NaN
# 1995        NaN        NaN   8.064746  0.080551  33.742542   9.844131    NaN
# 1996        NaN        NaN   9.571448  0.075840  34.385549  10.129188    NaN
# 1997        NaN  77.297851   8.379450  0.072735  34.978268   8.970577    NaN
# 1998        NaN  78.302779   5.703252  0.101829  35.711280   9.505661    NaN
# 1999        NaN  78.980861   7.278630  0.049495  36.329581   8.877752    NaN
# 2000  73.702495  78.479364  10.316367  0.031326  36.310596   7.453811    NaN
# 2001  74.944860  80.023047   8.050232  0.036476  36.306582   7.889282    NaN
# 2002  76.258066  77.999111   7.957603  0.039431  36.369508   7.757382    NaN
# 2003  77.120464  79.306311   9.539584  0.049157  36.416650   7.462984    NaN
# 2004  78.094440  79.537184  10.899546  0.038631  36.484362   6.760936    NaN
# 2005  79.062000  80.574728  13.506496  0.031945  36.540501   6.129071    NaN
# 2006  79.851681  84.621206  13.688121  0.034333  36.489221   5.813721    NaN
# 2007  80.570536  82.926878  12.303601  0.030291  36.494163   5.442958    NaN
# 2008  81.210886  83.644992  13.997417  0.042815  36.412954   4.648503    NaN
# 2009  81.809630  84.270921   8.721330  0.051040  36.372261   5.406126    NaN
# 2010  82.368101  86.959991   9.966140  0.052809  36.425990   5.177573    NaN
# 2011  82.783289  87.199474  13.002144  0.060245  36.440808   5.070097    NaN
# 2012  83.120303  87.512260  12.850205  0.061942  36.472300   5.014735    NaN
# 2013  83.533457  88.129881  11.641062  0.055593  36.534503   5.237570    NaN
# 2014  83.897596  87.275323  10.437876  0.079402  36.607475   5.184999    NaN
# 2015  84.171599  88.720097   6.277652  0.086177  36.624759   5.432857    NaN
# 2016  84.510171  89.308602   5.261868  0.076670  36.610850   5.482909    NaN
# 2017        NaN  90.283638   6.385551  0.085885        NaN   5.119066    NaN
# 2018        NaN  89.286856   8.190277  0.047916        NaN   4.735027    NaN
#
#       7          8      9      ...  16003     16004       16005    16006  \
# 1990    NaN        NaN    NaN  ...    NaN       NaN   98.952232  0.97075
# 1991    NaN        NaN    NaN  ...    NaN       NaN  105.350281  0.92799
# 1992    NaN        NaN    NaN  ...    NaN       NaN  104.232910  0.94515
# 1993    NaN        NaN    NaN  ...    NaN       NaN  108.267097      NaN
# 1994    NaN        NaN    NaN  ...    NaN       NaN         NaN      NaN
# 1995    NaN        NaN    NaN  ...    NaN       NaN  107.669647  0.94709
# 1996    NaN        NaN    NaN  ...    NaN -0.814238  106.532982  0.94928
# 1997    NaN        NaN    NaN  ...    NaN       NaN  106.316071      NaN
# 1998    NaN        NaN    NaN  ...    NaN -0.656564  104.982048      NaN
# 1999    NaN        NaN    NaN  ...    NaN       NaN  104.618423  0.94909
# 2000    NaN  32.034514    NaN  ...    NaN -1.340581  105.884323  0.94562
# 2001    NaN        NaN    NaN  ...    NaN       NaN  110.254539  0.94385
# 2002    NaN        NaN    NaN  ...    NaN -1.592860  105.328201  0.94233
# 2003    NaN        NaN    NaN  ...    NaN -1.700848  104.330650  0.94786
# 2004    NaN        NaN    NaN  ...    NaN -1.801661         NaN      NaN
# 2005    NaN        NaN    NaN  ...    NaN -1.818298         NaN      NaN
# 2006    NaN        NaN    NaN  ...    NaN -1.740026         NaN      NaN
# 2007    NaN        NaN    NaN  ...    NaN -1.798533         NaN      NaN
# 2008    NaN        NaN    NaN  ...    NaN -1.781623         NaN      NaN
# 2009    NaN        NaN    NaN  ...    NaN -1.852296         NaN      NaN
# 2010    NaN  24.113860    NaN  ...    NaN -1.823194         NaN      NaN
# 2011    NaN        NaN    NaN  ...    NaN -1.779670         NaN      NaN
# 2012    NaN        NaN    NaN  ...    NaN -1.629983  112.516792  0.96703
# 2013    NaN        NaN    NaN  ...    NaN -1.579165  109.892792  0.97012
# 2014    NaN        NaN    NaN  ...    NaN -1.431254         NaN      NaN
# 2015    NaN  19.715392    NaN  ...    NaN -1.317532         NaN      NaN
# 2016    NaN        NaN    NaN  ...    NaN -1.368230         NaN      NaN
# 2017    NaN        NaN    NaN  ...    NaN -1.377855         NaN      NaN
# 2018    NaN        NaN    NaN  ...    NaN -1.273343         NaN      NaN
#
#        16007  16008      16009  16010  16011     16012
# 1990     NaN    NaN        NaN    NaN    NaN       NaN
# 1991     NaN    NaN        NaN   4.80    NaN       NaN
# 1992     NaN    NaN        NaN   4.85    NaN       NaN
# 1993     NaN    NaN        NaN   4.93    NaN       NaN
# 1994     NaN    NaN        NaN   4.96   19.1       NaN
# 1995     NaN    NaN        NaN   5.58    NaN       NaN
# 1996     NaN    NaN        NaN   6.24    NaN -0.611550
# 1997     NaN    NaN        NaN   6.93    NaN       NaN
# 1998     NaN    NaN        NaN   6.44    NaN -0.789812
# 1999     NaN    NaN        NaN   6.00   16.7       NaN
# 2000  231.01    NaN        NaN   5.64    NaN -1.085388
# 2001  213.85    NaN        NaN   5.30    NaN       NaN
# 2002  165.61    NaN        NaN   5.03    NaN -1.363361
# 2003  180.57    NaN        NaN   4.72    NaN -1.431192
# 2004  138.17    NaN        NaN   4.39    NaN -1.553577
# 2005  139.50    NaN        NaN   4.48    NaN -1.674941
# 2006  172.45    NaN        NaN   4.52   15.5 -1.539244
# 2007  185.25    NaN        NaN   4.57    NaN -1.571521
# 2008  125.81    NaN        NaN   4.67    NaN -1.549031
# 2009  117.14    NaN        NaN   5.03    NaN -1.539211
# 2010  151.36    NaN        NaN   5.22    NaN -1.475183
# 2011  147.07    NaN        NaN   5.37   14.6 -1.463763
# 2012  202.94    NaN        NaN   5.38    NaN -1.471968
# 2013  223.58    5.0        NaN   5.38    NaN -1.386220
# 2014  273.00    5.0        NaN   5.33   10.4 -1.256964
# 2015  268.98    5.0        NaN   5.29   10.4 -1.165902
# 2016  313.80    5.0  27.214542   5.24    NaN -1.177471
# 2017  340.45    5.0  27.214585   5.15    NaN -1.194492
# 2018  359.33    5.0  27.214585   5.07    NaN -1.123221
#
# [29 rows x 16013 columns]

# %%
sweden = updated[[14214, 14219, 14223, 14237, 14251]].reset_index(drop=True)
sweden = sweden.rename({14214: 'CO2 emissions (metric tons per capita)', 14219: 'Electricity production from coal sources (% of total)', 14223: 'Fertility rate, total (births per woman)', 14237: 'Life expectancy at birth, total (years)', 14251: 'Population ages 65 and above (% of total population)'}, axis=1)
sweden
# Out:
#     CO2 emissions (metric tons per capita)  \
# 0                                 6.069368
# 1                                 5.979201
# 2                                 5.886699
# 3                                 5.936305
# 4                                 6.251746
# 5                                 6.248525
# 6                                 6.324031
# 7                                 5.895099
# 8                                 5.985460
# 9                                 5.769667
# 10                                5.562430
# 11                                5.747026
# 12                                6.434229
# 13                                6.115195
# 14                                6.062241
# 15                                5.710314
# 16                                5.459003
# 17                                5.253522
# 18                                5.328098
# 19                                4.631411
# 20                                5.547348
# 21                                5.474957
# 22                                4.942301
# 23                                4.671421
# 24                                4.484611
# 25                                3.896324
# 26                                4.358752
# 27                                     NaN
# 28                                     NaN
#
#     Electricity production from coal sources (% of total)  \
# 0                                            1.050115
# 1                                            1.667687
# 2                                            1.753508
# 3                                            1.912604
# 4                                            2.203924
# 5                                            1.982562
# 6                                            3.066268
# 7                                            1.838398
# 8                                            1.883608
# 9                                            2.028572
# 10                                           1.697985
# 11                                           1.979640
# 12                                           2.476483
# 13                                           3.076548
# 14                                           1.200609
# 15                                           0.887191
# 16                                           1.072680
# 17                                           0.907118
# 18                                           1.080097
# 19                                           0.651518
# 20                                           1.297993
# 21                                           0.971688
# 22                                           0.600231
# 23                                           0.729264
# 24                                           0.575042
# 25                                           0.666951
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
#
#     Fertility rate, total (births per woman)  \
# 0                                       2.13
# 1                                       2.11
# 2                                       2.09
# 3                                       1.99
# 4                                       1.88
# 5                                       1.73
# 6                                       1.60
# 7                                       1.52
# 8                                       1.50
# 9                                       1.50
# 10                                      1.54
# 11                                      1.57
# 12                                      1.65
# 13                                      1.71
# 14                                      1.75
# 15                                      1.77
# 16                                      1.85
# 17                                      1.88
# 18                                      1.91
# 19                                      1.94
# 20                                      1.98
# 21                                      1.90
# 22                                      1.91
# 23                                      1.89
# 24                                      1.88
# 25                                      1.85
# 26                                      1.85
# 27                                      1.78
# 28                                      1.76
#
#     Life expectancy at birth, total (years)  \
# 0                                 77.536829
# 1                                 77.666829
# 2                                 77.998780
# 3                                 78.060488
# 4                                 78.650244
# 5                                 78.740488
# 6                                 78.959024
# 7                                 79.197561
# 8                                 79.339024
# 9                                 79.441463
# 10                                79.643902
# 11                                79.795122
# 12                                79.846341
# 13                                80.095122
# 14                                80.497561
# 15                                80.546341
# 16                                80.748780
# 17                                80.900000
# 18                                81.100000
# 19                                81.351220
# 20                                81.451220
# 21                                81.802439
# 22                                81.704878
# 23                                81.956098
# 24                                82.253659
# 25                                82.204878
# 26                                82.307317
# 27                                82.409756
# 28                                82.558537
#
#     Population ages 65 and above (% of total population)
# 0                                           17.823737
# 1                                           17.823844
# 2                                           17.780380
# 3                                           17.702340
# 4                                           17.606386
# 5                                           17.508414
# 6                                           17.464292
# 7                                           17.427124
# 8                                           17.393805
# 9                                           17.353642
# 10                                          17.303685
# 11                                          17.304066
# 12                                          17.262595
# 13                                          17.218623
# 14                                          17.224598
# 15                                          17.306607
# 16                                          17.395947
# 17                                          17.548704
# 18                                          17.748755
# 19                                          17.974405
# 20                                          18.218566
# 21                                          18.501306
# 22                                          18.809760
# 23                                          19.120097
# 24                                          19.394672
# 25                                          19.608518
# 26                                          19.840195
# 27                                          19.991416
# 28                                          20.095525

# %%
finland = updated[[7045, 7050, 7054, 7068, 7082]].reset_index(drop=True)
finland = finland.rename({7045: 'CO2 emissions (metric tons per capita)', 7050: 'Electricity production from coal sources (% of total)', 7054: 'Fertility rate, total (births per woman)', 7068: 'Life expectancy at birth, total (years)', 7082: 'Population ages 65 and above (% of total population)'}, axis=1)
finland
# Out:
#     CO2 emissions (metric tons per capita)  \
# 0                                10.377169
# 1                                10.710477
# 2                                 9.415521
# 3                                 9.948375
# 4                                11.246028
# 5                                10.320143
# 6                                11.958636
# 7                                11.660578
# 8                                11.058284
# 9                                10.729516
# 10                               10.083843
# 11                               10.900614
# 12                               11.796511
# 13                               13.173168
# 14                               12.850911
# 15                               10.441602
# 16                               12.489865
# 17                               12.052027
# 18                               10.721357
# 19                               10.001213
# 20                               11.546566
# 21                               10.515892
# 22                                9.053082
# 23                                8.671667
# 24                                8.647964
# 25                                7.775642
# 26                                8.347220
# 27                                     NaN
# 28                                     NaN
#
#     Electricity production from coal sources (% of total)  \
# 0                                           18.460011
# 1                                           17.624944
# 2                                           14.108272
# 3                                           17.117176
# 4                                           22.265393
# 5                                           18.194737
# 6                                           22.360284
# 7                                           19.039840
# 8                                           12.249348
# 9                                           13.851736
# 10                                          13.107351
# 11                                          15.115592
# 12                                          17.804016
# 13                                          23.647511
# 14                                          19.960394
# 15                                          10.182483
# 16                                          20.757605
# 17                                          18.019570
# 18                                          11.883976
# 19                                          16.088748
# 20                                          18.755733
# 21                                          14.020217
# 22                                          10.783826
# 23                                          15.717754
# 24                                          12.359386
# 25                                           8.303570
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
#
#     Fertility rate, total (births per woman)  \
# 0                                       1.78
# 1                                       1.79
# 2                                       1.85
# 3                                       1.81
# 4                                       1.85
# 5                                       1.81
# 6                                       1.78
# 7                                       1.75
# 8                                       1.70
# 9                                       1.73
# 10                                      1.73
# 11                                      1.73
# 12                                      1.72
# 13                                      1.76
# 14                                      1.80
# 15                                      1.80
# 16                                      1.84
# 17                                      1.83
# 18                                      1.85
# 19                                      1.86
# 20                                      1.87
# 21                                      1.83
# 22                                      1.80
# 23                                      1.75
# 24                                      1.71
# 25                                      1.65
# 26                                      1.57
# 27                                      1.49
# 28                                      1.41
#
#     Life expectancy at birth, total (years)  \
# 0                                 74.813171
# 1                                 75.227561
# 2                                 75.455366
# 3                                 75.705122
# 4                                 76.395610
# 5                                 76.409512
# 6                                 76.693415
# 7                                 76.878537
# 8                                 77.090732
# 9                                 77.291220
# 10                                77.465854
# 11                                77.965854
# 12                                78.119512
# 13                                78.368293
# 14                                78.714634
# 15                                78.817073
# 16                                79.214634
# 17                                79.263415
# 18                                79.568293
# 19                                79.719512
# 20                                79.870732
# 21                                80.470732
# 22                                80.626829
# 23                                80.975610
# 24                                81.180488
# 25                                81.480488
# 26                                81.429268
# 27                                81.631707
# 28                                81.734146
#
#     Population ages 65 and above (% of total population)
# 0                                           13.435412
# 1                                           13.641242
# 2                                           13.828828
# 3                                           13.998177
# 4                                           14.148544
# 5                                           14.281193
# 6                                           14.435508
# 7                                           14.581076
# 8                                           14.720960
# 9                                           14.857168
# 10                                          14.993926
# 11                                          15.207182
# 12                                          15.416125
# 13                                          15.622182
# 14                                          15.825374
# 15                                          16.027053
# 16                                          16.199270
# 17                                          16.357771
# 18                                          16.546075
# 19                                          16.825120
# 20                                          17.229567
# 21                                          17.733140
# 22                                          18.343845
# 23                                          19.010782
# 24                                          19.658894
# 25                                          20.244377
# 26                                          20.790954
# 27                                          21.278753
# 28                                          21.720788

# %%
norway = updated[[11735, 11740, 11744, 11758, 11772]].reset_index(drop=True)
norway = norway.rename({11735: 'CO2 emissions (metric tons per capita)', 11740: 'Electricity production from coal sources (% of total)', 11744: 'Fertility rate, total (births per woman)', 11758: 'Life expectancy at birth, total (years)', 11772: 'Population ages 65 and above (% of total population)'}, axis=1)
norway
# Out:
#     CO2 emissions (metric tons per capita)  \
# 0                                 7.429148
# 1                                 7.526341
# 2                                 7.467627
# 3                                 8.151268
# 4                                 7.818332
# 5                                 7.671017
# 6                                 7.615493
# 7                                 8.195307
# 8                                 8.524820
# 9                                 9.117546
# 10                                8.834016
# 11                                9.284992
# 12                                8.378535
# 13                                9.906436
# 14                                9.287466
# 15                                9.179217
# 16                                9.495836
# 17                                9.574850
# 18                               11.679583
# 19                               11.461829
# 20                               10.108668
# 21                                8.559143
# 22                                8.866872
# 23                                9.495203
# 24                                9.328764
# 25                                9.099287
# 26                                7.836962
# 27                                     NaN
# 28                                     NaN
#
#     Electricity production from coal sources (% of total)  \
# 0                                            0.067428
# 1                                            0.078688
# 2                                            0.080265
# 3                                            0.074341
# 4                                            0.088139
# 5                                            0.069534
# 6                                            0.086917
# 7                                            0.072402
# 8                                            0.067851
# 9                                            0.067873
# 10                                           0.050522
# 11                                           0.078301
# 12                                           0.102119
# 13                                           0.121872
# 14                                           0.096270
# 15                                           0.096178
# 16                                           0.113016
# 17                                           0.100652
# 18                                           0.094195
# 19                                           0.074821
# 20                                           0.085201
# 21                                           0.104455
# 22                                           0.111154
# 23                                           0.113163
# 24                                           0.109045
# 25                                           0.104918
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
#
#     Fertility rate, total (births per woman)  \
# 0                                       1.93
# 1                                       1.92
# 2                                       1.88
# 3                                       1.86
# 4                                       1.87
# 5                                       1.87
# 6                                       1.89
# 7                                       1.86
# 8                                       1.81
# 9                                       1.85
# 10                                      1.85
# 11                                      1.78
# 12                                      1.75
# 13                                      1.80
# 14                                      1.83
# 15                                      1.84
# 16                                      1.90
# 17                                      1.90
# 18                                      1.96
# 19                                      1.98
# 20                                      1.95
# 21                                      1.88
# 22                                      1.85
# 23                                      1.78
# 24                                      1.75
# 25                                      1.72
# 26                                      1.71
# 27                                      1.62
# 28                                      1.56
#
#     Life expectancy at birth, total (years)  \
# 0                                 76.537317
# 1                                 76.980732
# 2                                 77.184390
# 3                                 77.151707
# 4                                 77.689756
# 5                                 77.736585
# 6                                 78.150488
# 7                                 78.142683
# 8                                 78.329268
# 9                                 78.282927
# 10                                78.634146
# 11                                78.785366
# 12                                78.987805
# 13                                79.390244
# 14                                79.841463
# 15                                80.041463
# 16                                80.343902
# 17                                80.395122
# 18                                80.592683
# 19                                80.795122
# 20                                80.997561
# 21                                81.295122
# 22                                81.451220
# 23                                81.751220
# 24                                82.100000
# 25                                82.304878
# 26                                82.407317
# 27                                82.609756
# 28                                82.758537
#
#     Population ages 65 and above (% of total population)
# 0                                           16.355954
# 1                                           16.371021
# 2                                           16.335332
# 3                                           16.256045
# 4                                           16.144269
# 5                                           16.009476
# 6                                           15.889342
# 7                                           15.746397
# 8                                           15.588065
# 9                                           15.422114
# 10                                          15.256435
# 11                                          15.147027
# 12                                          15.034913
# 13                                          14.933395
# 14                                          14.856877
# 15                                          14.815049
# 16                                          14.768968
# 17                                          14.733879
# 18                                          14.725051
# 19                                          14.769721
# 20                                          14.887334
# 21                                          15.110371
# 22                                          15.403985
# 23                                          15.731471
# 24                                          16.040052
# 25                                          16.303033
# 26                                          16.594219
# 27                                          16.834972
# 28                                          17.049222

# %%
plt.bar(sweden.index, sweden['CO2 emissions (metric tons per capita)'],color = 'gold')
plt.ylabel('CO2 emissions (metric tons per capita)')
plt.xlabel('Years since 1990')
plt.show()

# %%
plt.bar(sweden.index, sweden['Electricity production from coal sources (% of total)'], color = 'b')
plt.ylabel('Electricity production from coal sources (% of total)')
plt.xlabel('Years since 1990')
plt.show()

# %%
plt.plot(sweden.index, sweden['Life expectancy at birth, total (years)'], color = 'gold', linewidth = 5)
plt.ylabel('Life expectancy at birth, total (years)')
plt.xlabel('Years since 1990')
plt.show()

# %%
plt.plot(sweden.index, sweden['Population ages 65 and above (% of total population)'], color = 'gold', linewidth = 5)
plt.ylabel('Population ages 65 and above (% of total population)')
plt.xlabel('Years since 1990')
plt.show()

# %%
plt.plot(sweden.index, sweden['CO2 emissions (metric tons per capita)'], color = 'red', linewidth = 5, label = "Sweden")
plt.plot(finland.index, finland['CO2 emissions (metric tons per capita)'], color = 'blue', linewidth = 5, label = "Finland")
plt.plot(norway.index, norway['CO2 emissions (metric tons per capita)'], color = 'green', linewidth = 5, label = "Norway")
plt.ylabel('CO2 emissions (metric tons per capita)')
plt.xlabel('Years since 1990')
plt.legend(loc="lower left", prop={'size': 8})
plt.show()

# %%
plt.plot(sweden.index, sweden['Life expectancy at birth, total (years)'], color = 'red', linewidth = 5, label = "Sweden")
plt.plot(finland.index, finland['Life expectancy at birth, total (years)'], color = 'blue', linewidth = 5, label = "Finland")
plt.plot(norway.index, norway['Life expectancy at birth, total (years)'], color = 'green', linewidth = 5, label = "Norway")
plt.ylabel('Life expectancy at birth, total (years)')
plt.xlabel('Years since 1990')
plt.legend(loc="lower left", prop={'size': 8})
plt.show()

# %%
plt.bar(sweden.index, sweden['Population ages 65 and above (% of total population)'], color = 'red', linewidth = 5, label = "Sweden")
plt.bar(finland.index, finland['Population ages 65 and above (% of total population)'], color = 'blue', linewidth = 5, label = "Finland")
plt.bar(norway.index, norway['Population ages 65 and above (% of total population)'], color = 'green', linewidth = 5, label = "Norway")
plt.ylabel('Population ages 65 and above (% of total population)')
plt.xlabel('Years since 1990')
plt.legend(loc="lower left", prop={'size': 8})
plt.show()

# %%
print(ESGData.isnull().sum())
# Out:
# Country Name          0
# Country Code          0
# Indicator Name        0
# Indicator Code        0
# 1960              14661
#                   ...
# 2018               9315
# 2019              11753
# 2020              15550
# 2050              15241
# Unnamed: 66       16013
# Length: 67, dtype: int64

# %%
ESGData['1990'].fillna(ESGData['1990'].mean(), inplace=True)
ESGData['1990']
# Out:
# C:\Users\rocki\AppData\Local\Temp\ipykernel_2568\405372825.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ESGData['1990'].fillna(ESGData['1990'].mean(), inplace=True)
# 0        602.693254
# 1        602.693254
# 2          8.096032
# 3          0.052709
# 4         31.534601
#             ...
# 16008    602.693254
# 16009    602.693254
# 16010    602.693254
# 16011    602.693254
# 16012    602.693254
# Name: 1990, Length: 16013, dtype: float64

# %%
ESGData['1960'].fillna(ESGData['1960'].mean(), inplace=True)
ESGData['1961'].fillna(ESGData['1961'].mean(), inplace=True)
ESGData['1962'].fillna(ESGData['1962'].mean(), inplace=True)
ESGData['1963'].fillna(ESGData['1963'].mean(), inplace=True)
ESGData['1964'].fillna(ESGData['1964'].mean(), inplace=True)
ESGData['1965'].fillna(ESGData['1965'].mean(), inplace=True)
ESGData['2013'].fillna(ESGData['2013'].mean(), inplace=True)
ESGData['2014'].fillna(ESGData['2014'].mean(), inplace=True)
ESGData['2015'].fillna(ESGData['2015'].mean(), inplace=True)
ESGData['2016'].fillna(ESGData['2016'].mean(), inplace=True)
ESGData['2017'].fillna(ESGData['2017'].mean(), inplace=True)
ESGData['2018'].fillna(ESGData['2018'].mean(), inplace=True)
ESGData
# Out:
# C:\Users\rocki\AppData\Local\Temp\ipykernel_2568\308520975.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ESGData['1960'].fillna(ESGData['1960'].mean(), inplace=True)
# C:\Users\rocki\AppData\Local\Temp\ipykernel_2568\308520975.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ESGData['1961'].fillna(ESGData['1961'].mean(), inplace=True)
# C:\Users\rocki\AppData\Local\Temp\ipykernel_2568\308520975.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ESGData['1962'].fillna(ESGData['1962'].mean(), inplace=True)
# C:\Users\rocki\AppData\Local\Temp\ipykernel_2568\308520975.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ESGData['1963'].fillna(ESGData['1963'].mean(), inplace=True)
# C:\Users\rocki\AppData\Local\Temp\ipykernel_2568\308520975.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ESGData['1964'].fillna(ESGData['1964'].mean(), inplace=True)
# C:\Users\rocki\AppData\Local\Temp\ipykernel_2568\308520975.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ESGData['1965'].fillna(ESGData['1965'].mean(), inplace=True)
# C:\Users\rocki\AppData\Local\Temp\ipykernel_2568\308520975.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ESGData['2013'].fillna(ESGData['2013'].mean(), inplace=True)
# C:\Users\rocki\AppData\Local\Temp\ipykernel_2568\308520975.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ESGData['2014'].fillna(ESGData['2014'].mean(), inplace=True)
# C:\Users\rocki\AppData\Local\Temp\ipykernel_2568\308520975.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ESGData['2015'].fillna(ESGData['2015'].mean(), inplace=True)
# C:\Users\rocki\AppData\Local\Temp\ipykernel_2568\308520975.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ESGData['2016'].fillna(ESGData['2016'].mean(), inplace=True)
# C:\Users\rocki\AppData\Local\Temp\ipykernel_2568\308520975.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ESGData['2017'].fillna(ESGData['2017'].mean(), inplace=True)
# C:\Users\rocki\AppData\Local\Temp\ipykernel_2568\308520975.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ESGData['2018'].fillna(ESGData['2018'].mean(), inplace=True)
#       Country Name Country Code  \
# 0       Arab World          ARB
# 1       Arab World          ARB
# 2       Arab World          ARB
# 3       Arab World          ARB
# 4       Arab World          ARB
# ...            ...          ...
# 16008     Zimbabwe          ZWE
# 16009     Zimbabwe          ZWE
# 16010     Zimbabwe          ZWE
# 16011     Zimbabwe          ZWE
# 16012     Zimbabwe          ZWE
#
#                                           Indicator Name     Indicator Code  \
# 0      Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 1                Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 2      Adjusted savings: natural resources depletion ...  NY.ADJ.DRES.GN.ZS
# 3      Adjusted savings: net forest depletion (% of GNI)  NY.ADJ.DFOR.GN.ZS
# 4                     Agricultural land (% of land area)     AG.LND.AGRI.ZS
# ...                                                  ...                ...
# 16008  Strength of legal rights index (0=weak to 12=s...     IC.LGL.CRED.XQ
# 16009  Terrestrial and marine protected areas (% of t...     ER.PTD.TOTL.ZS
# 16010  Unemployment, total (% of total labor force) (...     SL.UEM.TOTL.ZS
# 16011  Unmet need for contraception (% of married wom...        SP.UWT.TFRT
# 16012                 Voice and Accountability: Estimate             VA.EST
#
#             1960       1961         1962       1963       1964       1965  \
# 0      84.690798  81.891646 -9870.967955  86.643651  88.523389  89.660521
# 1      84.690798  81.891646 -9870.967955  86.643651  88.523389  89.660521
# 2      84.690798  81.891646 -9870.967955  86.643651  88.523389  89.660521
# 3      84.690798  81.891646 -9870.967955  86.643651  88.523389  89.660521
# 4      84.690798  27.835643    27.826564  27.845522  27.847925  27.866972
# ...          ...        ...          ...        ...        ...        ...
# 16008  84.690798  81.891646 -9870.967955  86.643651  88.523389  89.660521
# 16009  84.690798  81.891646 -9870.967955  86.643651  88.523389  89.660521
# 16010  84.690798  81.891646 -9870.967955  86.643651  88.523389  89.660521
# 16011  84.690798  81.891646 -9870.967955  86.643651  88.523389  89.660521
# 16012  84.690798  81.891646 -9870.967955  86.643651  88.523389  89.660521
#
#        ...         2013         2014         2015         2016         2017  \
# 0      ...    83.533457    83.897596    84.171599    84.510171 -6139.049178
# 1      ...    88.129881    87.275323    88.720097    89.308602    90.283638
# 2      ...    11.641062    10.437876     6.277652     5.261868     6.385551
# 3      ...     0.055593     0.079402     0.086177     0.076670     0.085885
# 4      ...    36.534503    36.607475    36.624759    36.610850 -6139.049178
# ...    ...          ...          ...          ...          ...          ...
# 16008  ...     5.000000     5.000000     5.000000     5.000000     5.000000
# 16009  ...  3322.768026  3474.847542  3762.180464    27.214542    27.214585
# 16010  ...     5.380000     5.330000     5.290000     5.240000     5.150000
# 16011  ...  3322.768026    10.400000    10.400000  4630.373006 -6139.049178
# 16012  ...    -1.386220    -1.256964    -1.165902    -1.177471    -1.194492
#
#               2018      2019  2020  2050  Unnamed: 66
# 0      6505.281471       NaN   NaN   NaN          NaN
# 1        89.286856       NaN   NaN   NaN          NaN
# 2         8.190277       NaN   NaN   NaN          NaN
# 3         0.047916       NaN   NaN   NaN          NaN
# 4      6505.281471       NaN   NaN   NaN          NaN
# ...            ...       ...   ...   ...          ...
# 16008     5.000000  6.000000   NaN   NaN          NaN
# 16009    27.214585       NaN   NaN   NaN          NaN
# 16010     5.070000  5.020000  5.73   NaN          NaN
# 16011  6505.281471       NaN   NaN   NaN          NaN
# 16012    -1.123221 -1.141875   NaN   NaN          NaN
#
# [16013 rows x 67 columns]

# %%
X = ESGData[[ '1990', '1991', '1992', '1993' , '1994' , '1995' , '1996' ,'1997' , '1998' , '1999' , '2000' , '2001' , '2002' , '2003' , '2004', '2005' , '2006' , '2007', '2008' , '2009' , '2010' , '2011' , '2012' , '2013' , '2014' ,'2015', '2016' ,'2017' ,'2018']]
X
# Out:
#              1990        1991         1992        1993        1994  \
# 0      602.693254  612.103324 -6385.428073  717.064726  691.005909
# 1      602.693254  612.103324 -6385.428073  717.064726  691.005909
# 2        8.096032    8.368431     8.451037    8.247409    7.712396
# 3        0.052709    0.087444     0.070674    0.054602    0.058116
# 4       31.534601   31.639377    31.741282   32.458657   33.133486
# ...           ...         ...          ...         ...         ...
# 16008  602.693254  612.103324 -6385.428073  717.064726  691.005909
# 16009  602.693254  612.103324 -6385.428073  717.064726  691.005909
# 16010  602.693254    4.800000     4.850000    4.930000    4.960000
# 16011  602.693254  612.103324 -6385.428073  717.064726   19.100000
# 16012  602.693254  612.103324 -6385.428073  717.064726  691.005909
#
#              1995        1996          1997        1998        1999  ...  \
# 0      704.970582  633.837679 -10872.975600  635.927150  766.313258  ...
# 1      704.970582  633.837679     77.297851   78.302779   78.980861  ...
# 2        8.064746    9.571448      8.379450    5.703252    7.278630  ...
# 3        0.080551    0.075840      0.072735    0.101829    0.049495  ...
# 4       33.742542   34.385549     34.978268   35.711280   36.329581  ...
# ...           ...         ...           ...         ...         ...  ...
# 16008  704.970582  633.837679 -10872.975600  635.927150  766.313258  ...
# 16009  704.970582  633.837679 -10872.975600  635.927150  766.313258  ...
# 16010    5.580000    6.240000      6.930000    6.440000    6.000000  ...
# 16011  704.970582  633.837679 -10872.975600  635.927150   16.700000  ...
# 16012  704.970582   -0.611550 -10872.975600   -0.789812  766.313258  ...
#
#               2009         2010         2011         2012         2013  \
# 0        81.809630    82.368101    82.783289    83.120303    83.533457
# 1        84.270921    86.959991    87.199474    87.512260    88.129881
# 2         8.721330     9.966140    13.002144    12.850205    11.641062
# 3         0.051040     0.052809     0.060245     0.061942     0.055593
# 4        36.372261    36.425990    36.440808    36.472300    36.534503
# ...            ...          ...          ...          ...          ...
# 16008  2371.730710  2461.651767  2747.216978 -7212.071551     5.000000
# 16009  2371.730710  2461.651767  2747.216978 -7212.071551  3322.768026
# 16010     5.030000     5.220000     5.370000     5.380000     5.380000
# 16011  2371.730710  2461.651767    14.600000 -7212.071551  3322.768026
# 16012    -1.539211    -1.475183    -1.463763    -1.471968    -1.386220
#
#               2014         2015         2016         2017         2018
# 0        83.897596    84.171599    84.510171 -6139.049178  6505.281471
# 1        87.275323    88.720097    89.308602    90.283638    89.286856
# 2        10.437876     6.277652     5.261868     6.385551     8.190277
# 3         0.079402     0.086177     0.076670     0.085885     0.047916
# 4        36.607475    36.624759    36.610850 -6139.049178  6505.281471
# ...            ...          ...          ...          ...          ...
# 16008     5.000000     5.000000     5.000000     5.000000     5.000000
# 16009  3474.847542  3762.180464    27.214542    27.214585    27.214585
# 16010     5.330000     5.290000     5.240000     5.150000     5.070000
# 16011    10.400000    10.400000  4630.373006 -6139.049178  6505.281471
# 16012    -1.256964    -1.165902    -1.177471    -1.194492    -1.123221
#
# [16013 rows x 29 columns]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled
# Out:
# array([[ 1.22601116e-17,  1.21462721e-17, -1.03094948e-17, ...,
#         -8.77433966e-02,  2.37428673e-18,  0.00000000e+00],
#        [ 1.22601116e-17,  1.21462721e-17, -1.03094948e-17, ...,
#         -8.76507782e-02,  1.62620213e-02, -1.12499533e-01],
#        [-6.41220080e-02, -6.45028787e-02,  2.41590792e-02, ...,
#         -8.92730325e-02,  1.60430007e-02, -1.13921499e-01],
#        ...,
#        [ 1.22601116e-17, -6.48841289e-02,  2.41454728e-02, ...,
#         -8.92734546e-02,  1.60397752e-02, -1.13976211e-01],
#        [ 1.22601116e-17,  1.21462721e-17, -1.03094948e-17, ...,
#          1.75548971e-17,  2.37428673e-18,  0.00000000e+00],
#        [ 1.22601116e-17,  1.21462721e-17, -1.03094948e-17, ...,
#         -8.93973235e-02,  1.60232126e-02, -1.14084804e-01]])

# %%
k_values = range(2, 11)
k_values
# Out:
# range(2, 11)

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
silhouette_scores = []

for k in k_values:
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(X_scaled)
    silhouette_score_k = silhouette_score(X_scaled, kmeans.labels_)
    silhouette_scores.append(silhouette_score_k)

# %%
optimal_k = k_values[silhouette_scores.index(max(silhouette_scores))]
optimal_k
# Out:
# 2

# %%
kmeans = KMeans(n_clusters=optimal_k)
kmeans.fit(X_scaled)
# Out:
# KMeans(n_clusters=2)

# %%
KMeans(n_clusters=2)
# Out:
# KMeans(n_clusters=2)

# %%
country_clusters = kmeans.predict(X_scaled)
